# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n-cls.pt")

# %%
# hyperparams
learning_rate = 0.001
batch_size = 150
num_epochs = 25
image_size = 512

# %%
results = model.train(data="/users/gabon/Downloads/autos/", epochs=num_epochs, imgsz=image_size, batch=batch_size)
# Out:
# New https://pypi.org/project/ultralytics/8.0.212 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.210  Python-3.11.5 torch-2.1.0+cpu CPU (13th Gen Intel Core(TM) i7-13620H)
# ...

# %%
# hyperparams
learning_rate = 0.001
batch_size = 150
num_epochs = 40
image_size = 512

# %%
results2 = model.train(data="/users/gabon/Downloads/autos/", epochs=num_epochs, imgsz=image_size, batch=batch_size, weight_decay=1e-5)
# Out:
# New https://pypi.org/project/ultralytics/8.0.212 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.210  Python-3.11.5 torch-2.1.0+cpu CPU (13th Gen Intel Core(TM) i7-13620H)
# ...
